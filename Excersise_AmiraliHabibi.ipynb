# %% [markdown]
# # Excersise_AmiraliHabibi

# %% [markdown]
# # Introduction
# This notebook covers basic Data Science concepts, tools, and calculations.

# %% [markdown]
# # Data Science Languages
# - Python
# - R
# - SQL
# - Julia

# %% [markdown]
# ### Data Science Libraries
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn

# %% [markdown]
# ### Data Science Tools
# | Tool     | Purpose |
# |----------|---------|
# | Jupyter  | Code execution & documentation |
# | GitHub   | Version control |
# | Tableau  | Data visualization |

# %% [markdown]
# ### Arithmetic Examples
# In this section, we will show simple math operations using code cells.

# %% [markdown]
# ### Objectives
# 1. Learn Markdown
# 2. Practice basic arithmetic in Python
# 3. Explore Data Science tools

# %% [markdown]
# ### Author
# AmirAli Habibi

# %%
result = 5 * 2 + 10
print(result)
# Out:
# 20

# %%
minutes = 135
hours = minutes / 60
print(hours)
# Out:
# 2.25
